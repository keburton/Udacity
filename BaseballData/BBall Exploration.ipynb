# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
salaries_df = pd.read_csv('Salaries.csv')

# %%
salaries_df.head()
# Out:
#    yearID teamID lgID   playerID  salary
# 0    1985    ATL   NL  barkele01  870000
# 1    1985    ATL   NL  bedrost01  550000
# 2    1985    ATL   NL  benedbr01  545000
# 3    1985    ATL   NL   campri01  633333
# 4    1985    ATL   NL  ceronri01  625000

# %%
master_df = pd.read_csv('Master.csv')

# %%
master_df.head()
# Out:
#     playerID  birthYear  birthMonth  birthDay birthCountry birthState  \
# 0  aardsda01       1981          12        27          USA         CO
# 1  aaronha01       1934           2         5          USA         AL
# 2  aaronto01       1939           8         5          USA         AL
# 3   aasedo01       1954           9         8          USA         CA
# 4   abadan01       1972           8        25          USA         FL
#
#     birthCity  deathYear  deathMonth  deathDay    ...     nameLast  \
# 0      Denver        NaN         NaN       NaN    ...      Aardsma
# 1      Mobile        NaN         NaN       NaN    ...        Aaron
# 2      Mobile       1984           8        16    ...        Aaron
# 3      Orange        NaN         NaN       NaN    ...         Aase
# 4  Palm Beach        NaN         NaN       NaN    ...         Abad
#
#         nameGiven weight height bats throws       debut   finalGame   retroID  \
# ...

# %%
colleges_df = pd.read_csv('CollegePlaying.csv')

# %%
colleges_df.head()
# Out:
#     playerID schoolID  yearID
# 0  aardsda01   pennst    2001
# 1  aardsda01     rice    2002
# 2  aardsda01     rice    2003
# 3   abadan01  gamiddl    1992
# 4   abadan01  gamiddl    1993

# %%
schools_df = pd.read_csv('Schools.csv')

# %%
schools_df.head()
# Out:
#      schoolID                     name_full         city state country
# 0  abilchrist  Abilene Christian University      Abilene    TX     USA
# 1     adelphi            Adelphi University  Garden City    NY     USA
# 2    adrianmi                Adrian College       Adrian    MI     USA
# 3       akron           University of Akron        Akron    OH     USA
# 4     alabama         University of Alabama   Tuscaloosa    AL     USA

# %%
colleges_df['schoolID'] = 'NaN'

# %%
len(salaries_df)
# Out:
# 25575

# %%
len(colleges_df)
# Out:
# 17350

# %%
collegewinfo = pd.merge(colleges_df, schools_df, how='left', on=['schoolID'])

# %%
collegewinfo.head()
# Out:
#     playerID schoolID  yearID name_full city state country
# 0  aardsda01      NaN    2001       NaN  NaN   NaN     NaN
# 1  aardsda01      NaN    2002       NaN  NaN   NaN     NaN
# 2  aardsda01      NaN    2003       NaN  NaN   NaN     NaN
# 3   abadan01      NaN    1992       NaN  NaN   NaN     NaN
# 4   abadan01      NaN    1993       NaN  NaN   NaN     NaN

# %%
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18846 entries, 0 to 18845
# Data columns (total 24 columns):
# playerID        18846 non-null object
# birthYear       18703 non-null float64
# birthMonth      18531 non-null float64
# birthDay        18382 non-null float64
# birthCountry    18773 non-null object
# birthState      18220 non-null object
# birthCity       18647 non-null object
# deathYear       9336 non-null float64
# deathMonth      9335 non-null float64
# deathDay        9334 non-null float64
# deathCountry    9329 non-null object
# deathState      9277 non-null object
# deathCity       9325 non-null object
# nameFirst       18807 non-null object
# nameLast        18846 non-null object
# nameGiven       18807 non-null object
# weight          17975 non-null float64
# height          18041 non-null float64
# bats            17655 non-null object
# throws          17868 non-null object
# debut           18653 non-null object
# finalGame       18653 non-null object
# ...

# %%
new_master_df = master_df.drop(master_df.columns[[2,3,6,7,8,9,10,11,12,16,17,18,19,20,21,22,23]], axis=1)

# %%
new_master_df.head()
# Out:
#     playerID  birthYear birthCountry birthState nameFirst nameLast  \
# 0  aardsda01       1981          USA         CO     David  Aardsma
# 1  aaronha01       1934          USA         AL      Hank    Aaron
# 2  aaronto01       1939          USA         AL    Tommie    Aaron
# 3   aasedo01       1954          USA         CA       Don     Aase
# 4   abadan01       1972          USA         FL      Andy     Abad
#
#         nameGiven
# 0     David Allan
# 1     Henry Louis
# 2      Tommie Lee
# 3  Donald William
# 4   Fausto Andres

# %%
result = pd.merge(collegewinfo, new_master_df, how='outer', on=['playerID'])

# %%
result.head()
# Out:
#     playerID schoolID  yearID name_full city state country  birthYear  \
# 0  aardsda01      NaN    2001       NaN  NaN   NaN     NaN       1981
# 1  aardsda01      NaN    2002       NaN  NaN   NaN     NaN       1981
# 2  aardsda01      NaN    2003       NaN  NaN   NaN     NaN       1981
# 3   abadan01      NaN    1992       NaN  NaN   NaN     NaN       1972
# 4   abadan01      NaN    1993       NaN  NaN   NaN     NaN       1972
#
#   birthCountry birthState nameFirst nameLast      nameGiven
# 0          USA         CO     David  Aardsma    David Allan
# 1          USA         CO     David  Aardsma    David Allan
# 2          USA         CO     David  Aardsma    David Allan
# 3          USA         FL      Andy     Abad  Fausto Andres
# 4          USA         FL      Andy     Abad  Fausto Andres

# %%
result_sal = pd.merge(result, salaries_df, how='outer', on=['playerID'])

# %%
result_sal.head()
# Out:
#     playerID schoolID  yearID_x name_full city state country  birthYear  \
# 0  aardsda01      NaN      2001       NaN  NaN   NaN     NaN       1981
# 1  aardsda01      NaN      2001       NaN  NaN   NaN     NaN       1981
# 2  aardsda01      NaN      2001       NaN  NaN   NaN     NaN       1981
# 3  aardsda01      NaN      2001       NaN  NaN   NaN     NaN       1981
# 4  aardsda01      NaN      2001       NaN  NaN   NaN     NaN       1981
#
#   birthCountry birthState nameFirst nameLast    nameGiven  yearID_y teamID  \
# 0          USA         CO     David  Aardsma  David Allan      2004    SFN
# 1          USA         CO     David  Aardsma  David Allan      2007    CHA
# 2          USA         CO     David  Aardsma  David Allan      2008    BOS
# 3          USA         CO     David  Aardsma  David Allan      2009    SEA
# 4          USA         CO     David  Aardsma  David Allan      2010    SEA
#
#   lgID   salary
# 0   NL   300000
# 1   AL   387500
# 2   AL   403250
# ...

# %%
unique_players = result_sal.playerID.unique()

# %%
unique_players
# Out:
# array(['aardsda01', 'abadan01', 'abbeybe01', ..., 'rosajo01', 'arrueba01',
#        'furcara02'], dtype=object)

# %%
unique_salaries = set()
for id in unique_players:
    print id
    best_salary = float("-infinity")
    if np.logical_and(id,result_sal['playerID']) is True:
        if result_sal['salary'] > best_salary:
            best_salary = result_sal['salary']
    print best_salary
# Out:
# aardsda01
# -inf
# abadan01
# -inf
# abbeybe01
# -inf
# abbotje01
# -inf
# abbotji01
# -inf
# abbotky01
# -inf
# abercre01
# -inf
# abernte01
# -inf
# ablesha01
# -inf
# accarje01
# -inf
# aceveju01
# -inf
# ackerji01
# -inf
# ackledu01
# -inf
# acrema01
# -inf
# adairje01
# -inf
# adamsbo01
# -inf
# adamsbo04
# -inf
# adamsda02
# -inf
# adamsgl01
# -inf
# adamsjo02
# -inf
# adamsma01
# -inf
# adamsmi01
# -inf
# adamsmi03
# -inf
# adamsru01
# -inf
# adamssp02
# -inf
# adamswi02
# -inf
# adcocjo01
# -inf
# adducji01
# -inf
# aderhmo01
# -inf
# adkindo01
# -inf
# adkinhe01
# -inf
# adkinjo01
# -inf
# adkinst01
# -inf
# afenitr01
# -inf
# agbaybe01
# -inf
# ageeto01
# -inf
# agganha01
# -inf
# aguilri01
# -inf
# ahearpa01
# -inf
# aikenwi01
# -inf
# ainswku01
# -inf
# akerfda01
# -inf
# akerja01
# -inf
# albaljo01
# -inf
# alberan01
# -inf
# alberbu01
# -inf
# alberma01
# -inf
# albrija01
# -inf
# alderda01
# -inf
# aldremi01
# -inf
# aldrija01
# -inf
# aldrivi01
# -inf
# alexabo01
# ...
